# %% [markdown]
# # Capitulo 2 - Desenvolvendo um modelo de aprendizado de maquina

# %% [markdown]
# As libs utilizadas estão no [libs](/libs/).

# %% [markdown]
# ## Blueprint de desenvolvimento de modelo

# %%
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt

# %% [markdown]
# Formas de carregar os dados
#
# 1. CSV
# ```python
# data = pd.read_csv("xyz.csv", names=names)
# ```

# %% [markdown]
# 2. URL
# ```python
# URL = "https://goo.gl/vhm1eU"
#
# data = pd.read_csv(URL, names=['age', 'class']
# ```

# %% [markdown]
# 3. Usando pandas_data_reader

# %%
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']

# %%
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')

# %%
ccy_data['DEXJPUS'].plot()
plt.show()
